# %% [markdown]
# # Data Factory Fundamentals
#
# It's a web tool to manage complete complex ETL projects.
# It also includes integration services.
#
# We can use it to process a large volume of data.
#
# We can use it to retrieve data from local DB's.
#
# Data Factory will participate in all the ETL process bringing the data from a raw state to a curated state. For this state changes Data Factory uses Databricks.
#
# Finally we have to store the enriched data in a centralized data warehouse, it is also managed by Data Factory.
#
# ## Data storage
#
# It's a centralized data storage that can store structured, semi-structured, non-structured and realtime data.
#
# Azure Data factory is used as an Orchestrator for the complete process of the data
#
# ## Data lake
#
# Is a data storage for raw data.
#
# ## Databricks
#
# Service to compute, it will help us to manage the data.

# %% [markdown]
# # Data Engineers
#
# Responsible to organize the data so that others can easily access it.
#
# They have to work with different people/roles.
#
# Main responsibilities:
# * Get requirements of the data
# * Maintain meta data
# * Ensure security for the data
# * Data storage
# * Data processing
# * ETL tools

# %% [markdown]
# # Azure Data Factory Pipelines
#
# It's a flow of activities that perform an operation
# Commonly they have four steps:
#
# 1. Collect and store the raw data in a centralized source (Azure Data Lake)
# 2. Transform/Processing of the data
# 3. Publish the enriched information
# 4. Monitoring the pipeline
#
# Inside the pipelines we can find different activities, linked services, data Flows and Datasets
#
# ### Activities
#
# Individual steps within a pipeline in which every activity completes a single task
#
# There can be executed as sequential or parallel activities within the same pipeline
#
# They allow us to move or transform data and also to perform external tasks with services.
#
# ### Data Flows
#
# They are a type of activity.
#
# With them we can create data transformations easily.
#
# ### Datasets
#
# They are views that represent groups of data.
#
# ### Linked Services
#
# Connection from Data Factory to external resources.
#
# # Triggers
#
# With them we define the conditions to start a new pipeline
#
# # Templates
#
# They are templates for standard pipelines and are defined by Microsoft.

# %% [markdown]
# # Azure
#
# An azure account can have multiple Subscriptions. In a single subscription we can have multiple Resource Groups. Finally with a single Resource Group, we can create multiple resources.
#
# ## Azure Portal
#
# Home page from the portal:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Normally when we create a new resource, we should add it to a Resource group (it's a best practice)
#
# ### Creating a new resource:
#
# ![image-3.png](attachment:image-3.png)
#
# We can also look up for resources by name
#
# # Creating a Data Factory Resource:
#
# 1. In the home page of the portal, click the Create a resource button
# 2. Look up for "data factory"
# 3. Click in create
# 4. Name the Data Factory
# 5. Assign it to a resource group
# 6. Select were you want to allocate it
# 7. Go to the step by step configuration
# 8. Review your configurations
# 9. Create the Data Factory
# 10. To start working with the Data factory we have to Open Azure Data Factory Studio
#
# ![image-4.png](attachment:image-4.png)
#
# Once there, we can create all of the previous components that we looked at.
#
# ![image-5.png](attachment:image-5.png)
#
# Here we can find the monitoring section to monitor all the flows that we have.
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# # DB's in Azure
#
# When we have to decide the storage type for our the data we have to keep in mind two main factors:
# 1. Data Structure
#     * Structured
#     * Semi-structured
#     * No-structured
# 2. Requirements
#     * Amount of transactions
#     * Complexity of the queries
#     * Volume of the data for analytics
#     * Do we have to access multiple regions?
#
# ## Azure Cosmos DB
#
# It's is a globally distributed multi-model service.
#
# It can scale in performance and storage in many regions.
#
# Is Scheme-less (for NoSQL DBs) and can scale horizontally.
#
# We can store data in ARS format (type of JSON) format and also connect multiple APIs to it (SQL, MongoDB, Cassandra, Tables and Gremlin)
#
# ARS is a type of JSON that includes the sequence number.
#
# ### Types:
# 1. MongoDB: Key-value
# 2. Table API: Column-family
# 3. Gremlin: Document
# 4. Cassandra: Graph
#
#
# # CosmosDB
#
# With cosmos we can configure networking, backups, encryption, create tags, assign it to a resource group, etc.
#
# It works with different types of databases, NoSQL and SQL.
#
# It uses containers as storage methods. A container is like a db table
#
# ![image.png](attachment:image.png)
#
# CosmosDB works efficiently by partitioning the data by keys. This helps Cosmos to easily grow horizontally instead of vertically.
#
# ![image-2.png](attachment:image-2.png)
#
# Inside the container we can create tables and so we can create registers for those tables. We can specify as many fields as we want in the json object (the register) after we save the register, Cosmos will add new fields that help to optimize the performance of the queries.
#
# ![image-3.png](attachment:image-3.png)
#
# We can do Queries for all the containers.
#
# ![![image-4.png](attachment:image-4.png)](attachment:image-4.png)
#
# We can see the result of the queries, but also the metrics for that query. The more complex the query, the more we are going to be charged for it.
#
# ![image-5.png](attachment:image-5.png)
#
# # Azure SQL Database
#
# For relational databases, based on Microsoft SQL Server.
#
# It's a PaaS, with a 99.99% of uptime, we also have backups and maintenance with high performance.
#
# They are commonly used to store the results of Data Factory.
#
# We will need a server in order to run Azure SQL Database.
#
# To create a database we just have to look up for the service in the Azure Market Place and go through teh step-by-step guide.
#
# After creating the db, in order to access it, we will have to add the source ip (from we were we want to access). We can add an IP by:
#
# 1. Go to db  overview
# 2. Locate the Firewall settings
# 3. Click Add client IP
# 4. Create the access rule for our IP
# 5. Save changes
#
#
# Inside the Query editor we can see the tables, views and store procedures from the DB. We can also execute DML or DLL queries.
#
# # PostgreSQL and MySQL DB
#
# For relational DB's based in MySQL Community Edition.
#
# It offers:
#
# * 99.99% uptime
# * Integrated security
# * Redundancy
# * Data protection
# * Pay-as-you- go
# * Scalability
# * Automatic backups
#
# For PostgreSQL we have Azure Database for PostgreSQL, it offers:
#
# * High availability
# * Easy horizontal and vertical scaling
# * Automatic backups
# * Two implementation modes:
#     1. Unique Server: Vertical scaling
#     2. Hyper-scale: Horizontal scaling

# %% [markdown]
# # Azure Data Lakes
#
# Data repository to save data in it's original format.
#
# It can handle structured, semi-structured and no structured data for more than a petabyte of data.
#
# Azure Data Lake Storage Gen2 it's based on the Blob Storage capacities.
#
# It offers:
# * Better performance
# * Security
# * Easy to maintain
#
# Create a Data Lake:
#
# 1. Create an Storage Account
# 2. In the Hierarchical Namespace section (found inside the advanced steps of Storage account creation) click the select box
# ![image.png](attachment:image.png)
# 3. For the Blob storage configuration we can define the access tier (it will depend on the demand that we are going to handle)
# 4. Finish the step-by-step guide and create the resource.
# ![image-2.png](attachment:image-2.png)
# 5. We have to create a new container, after that we are gonna be able to store our data.
# ![image-3.png](attachment:image-3.png)
# 6. We can create a dashboard to centralize everything that is related to our data factory.

# %% [markdown]
# # Azure Storage
#
# An alternative to databases. Owned by Microsoft.
#
# We can access this services via HTTP or HTTPS
#
# It includes:
# * __Azure Blob Storage: Scaling objects storage__
# * Azure File Storage: Shared file storage
# * Azure Queue Storage: Message storage
# * __Azure Table Storage: For no structured data (NoSQL)__
#
# ## Azure Blob Storage
#
# Used to store objects, for non-structured data. It allows us to store lots of text or binary data and with it we can handle a massive amount of data.
#
# Ideal for:
# * Images or documents
# * Distributed access storage
# * Video and audio broadcast
# * Backups
# * 8TB Storage for VMs
#
# In order to use it we will need a Storage Account and a Container, within a Container we can store multiple Blobs
#
# We can configure different access levels in terms of access frequency, this can be configured in the Storage Account:
# 1. Hot: Frequently accessed data
# 2. Cool: Medium accessed data (storage period higher than 30 days)
# 3. Archive: Rarely accessed data (storage period higher than 180 days)
#
# To set the access level we can enter to Data Management (inside the Storage Account), then we go to Lifecycle management and we create a new rule based on our requirements.
#
# While creating a container we will have these options, it will depend on what we want to do with the container:
# ![image.png](attachment:image.png)
#
# Once a container is created, we could access it an load a file (a blob).
#
# ## Azure Table Storage
#
# It's a NoSQL DB for scheme-less key-value registers.
#
# To access this service we will need a Storage Account, a table and Entities (key-values).
#
# We can store multiple Entities in a table and also multiple tables in a single Storage Account.
#
# They have an associated URL.
#
# The Entities can store up to 1 MB of information.
#
# Each entity has many properties (key-value pairs). An entity can store up to 256 properties, they also store a property for the partition, row and time span.
#
# The partition number allow us to have atomic queries and optimize DML queries.
#
# The row number is the unique identifier for a row within a partition.
#
# The combination of this properties will help us to optimize the usage of the Azure Table Storage.
#
# In the web client for the Table Storage we can create and delete tables, but not access to the data stored on the tables. In order to access the data of the tables we have to look at it in the Storage Browser
#
# ![image-2.png](attachment:image-2.png)
#
# We can store different data types:
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Laboratory getting data from a Blob Storage
#
# Retrieve data from a Blob Storage and store it in a Data Lake using Data Factory
#
# 1. Create a Blob Storage
# 2. Create Data Lake
# 3. Load a csv file to the Blob Storage
# 4. Load the csv information to a Data Lake
#
# ## 1. Create Blob Storage
#
# ![image.png](attachment:image.png)
#
# Is an standard to add a prefix to give information about what are we creating, in this example we should add "bs" for Blob Storage:
#
# ![image-2.png](attachment:image-2.png)
#
# ## 2. Create Data Lake
#
# ![image-3.png](attachment:image-3.png)
#
# In this case we have to add the prefix "dl" to the storage account
#
# ![image-4.png](attachment:image-4.png)
#
# The only difference between the Blob Storage and the Data Lake is that when we are creating the Storage Account for the Data Lake, we have to mark this checkbox:
#
# ![image-5.png](attachment:image-5.png)
#
# Create a new container
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# After creating the container it will be displayed in the list of containers, we have to click it:
#
# ## 3. Load a csv file to the Blob Storage
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# ## 4. Load the csv information to a Data Lake
#
# ### Create container for dl
# First we have to move to the Data Lake (dl) that we created.
#
# Once inside the dl Storage account we have to create a new container:
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
#
# ### Transfer the information
#
# In order to complete the transfer from the Blob Storage to the Data Lake, we are going to se a pipeline.
#
# For the pipeline we are going to need:
#
# 1. Linked Services for the Blob Storage (to access the BL)
# 2. Linked Services for the Data Lake (To access the DL)
# 3. Dataset from the BL
# 4. Destination Dataset
# * The transfer activity
# * The pipeline to store the previous activities
#
# All of this services should be created following the prefix standard that we saw before
#
# For the linked services the standard follows:
#
# ls_source_storage
#
# * ls --> Linked Services
# * source --> Where the ls grants access to
# * storage --> The Storage account corresponding to the source
#
# __Dataset standards__
#
# ds_data_type_source
#
# * ds --> Dataset
# * data --> Source file name
# * type --> Datatype under which it will be stored in the destination container
# * source --> Data source
#
# __Pipelines__
#
# With pipelines we just have to add the pl prefix and the rest of the name is a brief description of what is done inside that pipeline
#
# ## Linked Services
#
# They define how we are going to access specific resources. They are similar to the connection strings, in which we define everything that we are going to need in order to successfully connect to the resource that we want.
#
# They are mainly used for:
#
# * Represent a data storage
# * Represent a resource process
#
# To create them we have to go to the Data Factory that we created and enter Azure Data Factory Studio, then we go to the "manage" button and inside we will find the Linked Services
#
# ![image-13.png](attachment:image-13.png)
#
# ### 1. Creating the Linked Service for the Blob Storage (to access the BL)
#
# We could search for it by typing the name or by sliding down.
#
# ![image-14.png](attachment:image-14.png)
#
# We have to create it using the standard that we saw before
#
# ![image-15.png](attachment:image-15.png)
#
# After we have finished the configuration we should be able to test it
#
# ![image-16.png](attachment:image-16.png)
#
# ### 2. Linked Services for the Data Lake (To access the DL)
#
# We have to look for the service in Data Factory Studio
#
# ![image-17.png](attachment:image-17.png)
#
# Remember to name the service using the prefix syntax:
#
# ![image-18.png](attachment:image-18.png)
#
# Complete the rest of the information and test connection
#
# ![image-19.png](attachment:image-19.png)
#
# __Finished with the linked services creation__
#
# ![image-20.png](attachment:image-20.png)
#
# ## Datasets
#
# They represent the data structures for the data that we want to use.
#
# They help us to define the data source, its format and the path to reach the data source.
#
# __Create a new dataset__
#
# We have to enter Data Factory Studio, then to author button.
#
# There we will find an option to add a new dataset, we have to click it.
#
# ![image-21.png](attachment:image-21.png)
#
# ### 3. Dataset from the BL
#
# We have to look for the bl to create a new dataset
#
# ![image-22.png](attachment:image-22.png)
#
# After we selected the blob storage it will show us all the different data formats that we can select, for this laboratory we are going to use Delimited Text (csv format)
#
# ![image-23.png](attachment:image-23.png)
#
# We have to set the name using the standards that we saw, then we have to add the linked service that we created in the first step.
# ![image-24.png](attachment:image-24.png)
#
# After doing so we can type the path to the data or we could just browse to it:
#
# ![image-25.png](attachment:image-25.png)
#
# After creating it, we will see the confirmation with the dataset info
#
# ![image-26.png](attachment:image-26.png)
#
# Datasets can also work with compressed files.
#
# Before continuing we should look at the preview of our data, just to check that everything is configured correctly.
#
# We can also check the Schema to confirm the data types that we are retrieving from the source are correct.
#
# ![image-27.png](attachment:image-27.png)
#
#
# ### 4. Destination Dataset
#
# The process to create it is quite similar to the bs dataset.
#
# As it is a destination dataset we just have to specify where we want to store the result. We are not going to retrieve data from this dataset, we are going to store dat in it.
#
# ![image-28.png](attachment:image-28.png)
#
# Finally we have to test the connection and add a file name, it's where we will store the information.
#
# ![image-29.png](attachment:image-29.png)
#
# __Confirm the steps 3 and 4__
#
# We just have to click in validate all to confirm that there are no issues related to the datasets configuration.
#
# ![image-30.png](attachment:image-30.png)
#
# Finally we have to publish our datasets.
#
# By default in Author configuration, Azure does not save our progress automatically, so we have to publish everything, otherwise we will loose everything that we have configured.
#
# ![image-31.png](attachment:image-31.png)
